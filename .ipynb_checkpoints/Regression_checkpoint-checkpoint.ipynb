# %%
#import data
import pandas as pd
df=pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
from datetime import datetime
df['date']=df['date'].apply(lambda x: x[:8])
pd.to_datetime(df['date'], format='%Y%m%d')
df['date'].describe()
# Out:
# count        21613
# unique         372
# top       20140623
# freq           142
# Name: date, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#which features that are important or not important to the price
#link betwwen sqft_living and sqft_living15, same for: sqft_lot and sqft_lot15
#show outliers for the iportant features

def plot_correlation_map( df, m ):
    corr = df.corr()
    s , ax = plt.subplots( figsize =( m , m ) )
    cmap = sns.diverging_palette( 256, 0 , as_cmap = True )
    s = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 10 }
        )

# %%
# first: which features that are important or not important to the price
#Try running the function, analyse what does it do exactly and what are the utilities of it,
plot_correlation_map( df, 12 )

# from the following graph the id is clearly unsignificant feature

# %%
df_new= df.drop('id', axis='columns', inplace=False)
df_new= df_new.drop('zipcode', axis='columns', inplace=False)
plot_correlation_map( df_new, 10 )

#sqft_living and sqft_lot have a high correlations with sqft_living15 and sqft_lot15 
#but sqft_living and sqft_lot have the highest impact on the price

# %%
df_new= df_new.drop('sqft_living15', axis='columns', inplace=False)
df_new= df_new.drop('sqft_lot15', axis='columns', inplace=False)
plot_correlation_map( df_new, 10 )

#from the correlation graph, it is preffered to do a regression on (all the rest features) 
#and an other regression on (bedrooms, bathrooms, sqrt_living, grade, sqrt_above, view)

# %%
df_all = df_new
df_small=df_new[['price','bedrooms','bathrooms', 'sqft_living', 'grade', 'sqft_above', 'sqft_basement','view']]
df_small.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  grade  sqft_above  \
# 0  221900.0         3       1.00         1180      7        1180
# 1  538000.0         3       2.25         2570      7        2170
# 2  180000.0         2       1.00          770      6         770
# 3  604000.0         4       3.00         1960      7        1050
# 4  510000.0         3       2.00         1680      8        1680
#
#    sqft_basement  view
# 0              0     0
# 1            400     0
# 2              0     0
# 3            910     0
# 4              0     0

# %%
plot_correlation_map( df_small)

# %%
plt.ylabel('price')
plt.xlabel('bedrooms')
plt.scatter(df_small['bedrooms'], df_small['price'])

# %%
plt.ylabel('price')
plt.xlabel('bathrooms')
plt.scatter(df_small['bathrooms'],df_small['price'])

# %%
plt.ylabel('price')
plt.xlabel('sqft_living')
plt.scatter(df_small['sqft_living'],df_small['price'])

# %%
plt.xlabel('grade')
plt.ylabel('price')
plt.scatter(df_small['grade'],df_small['price'])

# %%
plt.xlabel('sqft_above')
plt.ylabel('price')
plt.scatter(df_small['sqft_above'],df_small['price'])

# %%
plt.ylabel('sqft_basement')
plt.xlabel('price')
plt.scatter(df_small['sqft_basement'],df_small['price'])

# %%
plt.ylabel('view')
plt.xlabel('price')
plt.scatter(df_small['view'],df_small['price'])

# %%
sns.boxplot(df_small['bedrooms'], width=0.5)

# %%
sns.boxplot(df_small['bathrooms'], width=0.5)

# %%
sns.boxplot(df_small['sqft_living'], width=0.5)

# %%
sns.boxplot(df_small['grade'], width=0.5)

# %%
sns.boxplot(df_small['sqft_above'], width=0.5)

# %%
sns.boxplot(df_small['sqft_basement'], width=0.5)

# %%
sns.boxplot(df_small['view'], width=0.5)

# %%
sns.boxplot(df_small['price'], width=0.5)

# %%
#remove all outliers
from scipy import stats
import numpy as np
df_small_reduced = df_small
df_small_reduced=df_small_reduced[(np.abs(stats.zscore(df_small_reduced)) < 3).all(axis=1)]
df_small_reduced
# Out:
#           price  bedrooms  bathrooms  sqft_living  grade  sqft_above  \
# 0      221900.0         3       1.00         1180      7        1180
# 1      538000.0         3       2.25         2570      7        2170
# 2      180000.0         2       1.00          770      6         770
# 3      604000.0         4       3.00         1960      7        1050
# 4      510000.0         3       2.00         1680      8        1680
# ...         ...       ...        ...          ...    ...         ...
# 21608  360000.0         3       2.50         1530      8        1530
# 21609  400000.0         4       2.50         2310      8        2310
# 21610  402101.0         2       0.75         1020      7        1020
# 21611  400000.0         3       2.50         1600      8        1600
# 21612  325000.0         2       0.75         1020      7        1020
#
#        sqft_basement  view
# 0                  0     0
# 1                400     0
# 2                  0     0
# ...

# %%
sns.boxplot(df_small_reduced['bedrooms'], width=0.5)

# %%
sns.boxplot(df_small_reduced['bathrooms'], width=0.5)

# %%
sns.boxplot(df_small_reduced['sqft_living'], width=0.5)

# %%
sns.boxplot(df_small_reduced['grade'], width=0.5)

# %%
sns.boxplot(df_small_reduced['price'], width=0.5)

# %%
sns.boxplot(df_small_reduced['view'], width=0.5)

# %%
#linear regression on df_all
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

#same for df_all and df_small

#extract x and y from our data
x=df_all["sqft_living"].values[:,np.newaxis]
y=df_all["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

#error measurement
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))

plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()
# Out:
# MSE 62902408306.86502
# R squared 0.4996528488387417

# %%
#extract x and y from our data
x=df_small_reduced["sqft_living"].values[:,np.newaxis]
y=df_small_reduced["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

#error measurement
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))

plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()
# Out:
# MSE 33137958023.0964
# R squared 0.3932842186024449

# %%
#Multi-linear Regression Code
#extract x and y from our data
x=df_small[['bedrooms','bathrooms', 'sqft_living', 'grade', 'sqft_above', 'sqft_basement','view']]  #we have more than one input
y=df_small["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 52396521376.30424
# R squared 0.58322024693397

# %%
#Multi-linear Regression Code
#extract x and y from our data
x=df_small_reduced[['bedrooms','bathrooms', 'sqft_living', 'grade', 'sqft_above', 'sqft_basement','view']]  #we have more than one input
y=df_small_reduced["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 27605214988.021397
# R squared 0.49458202673708607

# %%
#Multi-linear Regression Code
#extract x and y from our data
x=df_all[['bedrooms','bathrooms', 'sqft_living', 'grade', 'sqft_above', 'sqft_basement','view']]  #we have more than one input
y=df_all["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 52396521376.30424
# R squared 0.58322024693397

# %%
#polynomial regression with outliers on these features: 
#'price','bedrooms','bathrooms', 'sqft_living', 'grade', 'sqft_above', 'sqft_basement','view'

from sklearn.preprocessing import PolynomialFeatures 

from sklearn.metrics import mean_squared_error
from sklearn import metrics

x= df_small[['sqft_living', 'grade']]
y= df_small["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
